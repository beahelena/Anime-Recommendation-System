# %%
import pandas as pd
animes = pd.read_csv("anime-dataset-2023.csv")

# %%
animes
# Out:
#        anime_id                             Name             English name  \
# 0             1                     Cowboy Bebop             Cowboy Bebop
# 1             5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2             6                           Trigun                   Trigun
# 3             7               Witch Hunter Robin       Witch Hunter Robin
# 4             8                   Bouken Ou Beet   Beet the Vandel Buster
# ...         ...                              ...                      ...
# 24900     55731                      Wu Nao Monu                  UNKNOWN
# 24901     55732              Bu Xing Si: Yuan Qi              Blader Soul
# 24902     55733                      Di Yi Xulie          The First Order
# 24903     55734         Bokura no Saishuu Sensou                  UNKNOWN
# 24904     55735                   Shijuuku Nichi                  UNKNOWN
#
#                              Other name    Score  \
# 0                             カウボーイビバップ     8.75
# 1                        カウボーイビバップ 天国の扉     8.38
# 2                                 トライガン     8.22
# 3      Witch Hunter ROBIN (ウイッチハンターロビン)     7.25
# 4                                冒険王ビィト     6.94
# ...                                 ...      ...
# 24900                              无脑魔女  UNKNOWN
# 24901                            捕星司·源起  UNKNOWN
# 24902                              第一序列  UNKNOWN
# 24903                           僕らの最終戦争  UNKNOWN
# 24904                              四十九日  UNKNOWN
#
#                                      Genres  \
# 0             Action, Award Winning, Sci-Fi
# 1                            Action, Sci-Fi
# 2                 Action, Adventure, Sci-Fi
# 3      Action, Drama, Mystery, Supernatural
# 4          Adventure, Fantasy, Supernatural
# ...                                     ...
# 24900        Comedy, Fantasy, Slice of Life
# 24901            Action, Adventure, Fantasy
# 24902    Action, Adventure, Fantasy, Sci-Fi
# 24903                               UNKNOWN
# 24904                               UNKNOWN
#
#                                                 Synopsis   Type Episodes  \
# 0      Crime is timeless. By the year 2071, humanity ...     TV     26.0
# 1      Another day, another bounty—such is the life o...  Movie      1.0
# 2      Vash the Stampede is the man with a $$60,000,0...     TV     26.0
# 3      Robin Sena is a powerful craft user drafted in...     TV     26.0
# 4      It is the dark century and the people are suff...     TV     52.0
# ...                                                  ...    ...      ...
# 24900           No description available for this anime.    ONA     15.0
# 24901           No description available for this anime.    ONA     18.0
# 24902           No description available for this anime.    ONA     16.0
# 24903  A music video for the song Bokura no Saishuu S...  Music      1.0
# 24904  A music video for the song Shijuuku Nichi by S...  Music      1.0
#
#                               Aired  ...         Studios     Source  \
# 0       Apr 3, 1998 to Apr 24, 1999  ...         Sunrise   Original
# 1                       Sep 1, 2001  ...           Bones   Original
# 2       Apr 1, 1998 to Sep 30, 1998  ...        Madhouse      Manga
# 3       Jul 3, 2002 to Dec 25, 2002  ...         Sunrise   Original
# 4      Sep 30, 2004 to Sep 29, 2005  ...  Toei Animation      Manga
# ...                             ...  ...             ...        ...
# 24900              Jul 4, 2023 to ?  ...         UNKNOWN  Web manga
# 24901             Jul 27, 2023 to ?  ...         UNKNOWN  Web novel
# 24902             Jul 19, 2023 to ?  ...         UNKNOWN  Web novel
# 24903                  Apr 23, 2022  ...         UNKNOWN   Original
# 24904                   Sep 5, 2022  ...         UNKNOWN   Original
#
#             Duration                          Rating     Rank Popularity  \
# 0      24 min per ep  R - 17+ (violence & profanity)     41.0         43
# 1        1 hr 55 min  R - 17+ (violence & profanity)    189.0        602
# 2      24 min per ep       PG-13 - Teens 13 or older    328.0        246
# 3      25 min per ep       PG-13 - Teens 13 or older   2764.0       1795
# 4      23 min per ep                   PG - Children   4240.0       5126
# ...              ...                             ...      ...        ...
# 24900        Unknown       PG-13 - Teens 13 or older  UNKNOWN      24723
# 24901        Unknown       PG-13 - Teens 13 or older      0.0          0
# 24902        Unknown       PG-13 - Teens 13 or older      0.0          0
# 24903          3 min       PG-13 - Teens 13 or older      0.0          0
# 24904          3 min       PG-13 - Teens 13 or older      0.0          0
#
#       Favorites Scored By  Members  \
# 0         78525  914193.0  1771505
# 1          1448  206248.0   360978
# 2         15035  356739.0   727252
# 3           613   42829.0   111931
# 4            14    6413.0    15001
# ...         ...       ...      ...
# 24900         0   UNKNOWN        0
# 24901         0   UNKNOWN        0
# 24902         0   UNKNOWN        0
# 24903         0   UNKNOWN        0
# 24904         0   UNKNOWN        0
#
#                                                Image URL
# 0      https://cdn.myanimelist.net/images/anime/4/196...
# 1      https://cdn.myanimelist.net/images/anime/1439/...
# 2      https://cdn.myanimelist.net/images/anime/7/203...
# 3      https://cdn.myanimelist.net/images/anime/10/19...
# 4      https://cdn.myanimelist.net/images/anime/7/215...
# ...                                                  ...
# 24900  https://cdn.myanimelist.net/images/anime/1386/...
# 24901  https://cdn.myanimelist.net/images/anime/1383/...
# 24902  https://cdn.myanimelist.net/images/anime/1130/...
# 24903  https://cdn.myanimelist.net/images/anime/1931/...
# 24904  https://cdn.myanimelist.net/images/anime/1902/...
#
# [24905 rows x 24 columns]

# %%
import re
#def clean_title(title):
    #return re.sub("[^a-zA-Z0-9 ]","",Name)

# %%
#adiciona uma nova coluna com o cabeçalho "clean_title"
#animes["clean_title"] = animes["Name"].apply(clean_title)

# %%
animes
# Out:
#        anime_id                             Name             English name  \
# 0             1                     Cowboy Bebop             Cowboy Bebop
# 1             5  Cowboy Bebop: Tengoku no Tobira  Cowboy Bebop: The Movie
# 2             6                           Trigun                   Trigun
# 3             7               Witch Hunter Robin       Witch Hunter Robin
# 4             8                   Bouken Ou Beet   Beet the Vandel Buster
# ...         ...                              ...                      ...
# 24900     55731                      Wu Nao Monu                  UNKNOWN
# 24901     55732              Bu Xing Si: Yuan Qi              Blader Soul
# 24902     55733                      Di Yi Xulie          The First Order
# 24903     55734         Bokura no Saishuu Sensou                  UNKNOWN
# 24904     55735                   Shijuuku Nichi                  UNKNOWN
#
#                              Other name    Score  \
# 0                             カウボーイビバップ     8.75
# 1                        カウボーイビバップ 天国の扉     8.38
# 2                                 トライガン     8.22
# 3      Witch Hunter ROBIN (ウイッチハンターロビン)     7.25
# 4                                冒険王ビィト     6.94
# ...                                 ...      ...
# 24900                              无脑魔女  UNKNOWN
# 24901                            捕星司·源起  UNKNOWN
# 24902                              第一序列  UNKNOWN
# 24903                           僕らの最終戦争  UNKNOWN
# 24904                              四十九日  UNKNOWN
#
#                                      Genres  \
# 0             Action, Award Winning, Sci-Fi
# 1                            Action, Sci-Fi
# 2                 Action, Adventure, Sci-Fi
# 3      Action, Drama, Mystery, Supernatural
# 4          Adventure, Fantasy, Supernatural
# ...                                     ...
# 24900        Comedy, Fantasy, Slice of Life
# 24901            Action, Adventure, Fantasy
# 24902    Action, Adventure, Fantasy, Sci-Fi
# 24903                               UNKNOWN
# 24904                               UNKNOWN
#
#                                                 Synopsis   Type Episodes  \
# 0      Crime is timeless. By the year 2071, humanity ...     TV     26.0
# 1      Another day, another bounty—such is the life o...  Movie      1.0
# 2      Vash the Stampede is the man with a $$60,000,0...     TV     26.0
# 3      Robin Sena is a powerful craft user drafted in...     TV     26.0
# 4      It is the dark century and the people are suff...     TV     52.0
# ...                                                  ...    ...      ...
# 24900           No description available for this anime.    ONA     15.0
# 24901           No description available for this anime.    ONA     18.0
# 24902           No description available for this anime.    ONA     16.0
# 24903  A music video for the song Bokura no Saishuu S...  Music      1.0
# 24904  A music video for the song Shijuuku Nichi by S...  Music      1.0
#
#                               Aired  ...         Studios     Source  \
# 0       Apr 3, 1998 to Apr 24, 1999  ...         Sunrise   Original
# 1                       Sep 1, 2001  ...           Bones   Original
# 2       Apr 1, 1998 to Sep 30, 1998  ...        Madhouse      Manga
# 3       Jul 3, 2002 to Dec 25, 2002  ...         Sunrise   Original
# 4      Sep 30, 2004 to Sep 29, 2005  ...  Toei Animation      Manga
# ...                             ...  ...             ...        ...
# 24900              Jul 4, 2023 to ?  ...         UNKNOWN  Web manga
# 24901             Jul 27, 2023 to ?  ...         UNKNOWN  Web novel
# 24902             Jul 19, 2023 to ?  ...         UNKNOWN  Web novel
# 24903                  Apr 23, 2022  ...         UNKNOWN   Original
# 24904                   Sep 5, 2022  ...         UNKNOWN   Original
#
#             Duration                          Rating     Rank Popularity  \
# 0      24 min per ep  R - 17+ (violence & profanity)     41.0         43
# 1        1 hr 55 min  R - 17+ (violence & profanity)    189.0        602
# 2      24 min per ep       PG-13 - Teens 13 or older    328.0        246
# 3      25 min per ep       PG-13 - Teens 13 or older   2764.0       1795
# 4      23 min per ep                   PG - Children   4240.0       5126
# ...              ...                             ...      ...        ...
# 24900        Unknown       PG-13 - Teens 13 or older  UNKNOWN      24723
# 24901        Unknown       PG-13 - Teens 13 or older      0.0          0
# 24902        Unknown       PG-13 - Teens 13 or older      0.0          0
# 24903          3 min       PG-13 - Teens 13 or older      0.0          0
# 24904          3 min       PG-13 - Teens 13 or older      0.0          0
#
#       Favorites Scored By  Members  \
# 0         78525  914193.0  1771505
# 1          1448  206248.0   360978
# 2         15035  356739.0   727252
# 3           613   42829.0   111931
# 4            14    6413.0    15001
# ...         ...       ...      ...
# 24900         0   UNKNOWN        0
# 24901         0   UNKNOWN        0
# 24902         0   UNKNOWN        0
# 24903         0   UNKNOWN        0
# 24904         0   UNKNOWN        0
#
#                                                Image URL
# 0      https://cdn.myanimelist.net/images/anime/4/196...
# 1      https://cdn.myanimelist.net/images/anime/1439/...
# 2      https://cdn.myanimelist.net/images/anime/7/203...
# 3      https://cdn.myanimelist.net/images/anime/10/19...
# 4      https://cdn.myanimelist.net/images/anime/7/215...
# ...                                                  ...
# 24900  https://cdn.myanimelist.net/images/anime/1386/...
# 24901  https://cdn.myanimelist.net/images/anime/1383/...
# 24902  https://cdn.myanimelist.net/images/anime/1130/...
# 24903  https://cdn.myanimelist.net/images/anime/1931/...
# 24904  https://cdn.myanimelist.net/images/anime/1902/...
#
# [24905 rows x 24 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(ngram_range=(1,2))

tfidf = vectorizer.fit_transform(animes["Name"])

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

def search(Name):
    #Anime = clean_title(Name)
    #transforma o título limpo do anime em uma representação vetorial 
    query_vec = vectorizer.transform([Name])
    similarity = cosine_similarity(query_vec, tfidf).flatten()
    indices = np.argpartition(similarity, -5)[-5:]
    results = animes.iloc[indices][::-1]
    return results

# %%
import ipywidgets as widgets
from IPython.display import display

#widget em que será fornecido do nome do anime
anime_input = widgets.Text(
    value = " ",
    description = "Anime Title:",
    disabled = False)

#esse é o widget que exibe os resultados de saída
anime_list = widgets.Output()

def on_type(data):
    with anime_list:
        anime_list.clear_output() #limpa o output
        Name = data["new"]
        if len(Name) > 3:
            display(search(Name))

anime_input.observe(on_type, names='value') #observa sempre que há uma mudança em anime_input,
                                            #chamando automaticamente a função on_type
display(anime_input, anime_list)
# Out:
# Text(value=' ', description='Anime Title:')
# Output()

# %%
ratings = pd.read_csv("users-score-2023.csv")

# %%
ratings
# Out:
#           user_id    Username  anime_id             Anime Title  rating
# 0               1       Xinil        21               One Piece       9
# 1               1       Xinil        48             .hack//Sign       7
# 2               1       Xinil       320                  A Kite       5
# 3               1       Xinil        49        Aa! Megami-sama!       8
# 4               1       Xinil       304  Aa! Megami-sama! Movie       8
# ...           ...         ...       ...                     ...     ...
# 24325186  1291087   Oblongata     10611                    R-15       3
# 24325187  1291087   Oblongata       174            Tenjou Tenge       6
# 24325188  1291097  JuunanaSai      1535              Death Note       9
# 24325189  1291097  JuunanaSai       226              Elfen Lied      10
# 24325190  1291097  JuunanaSai      8425                  Gosick      10
#
# [24325191 rows x 5 columns]

# %%
#acha os usuarios que gostaram dos mesmos animes
similar_users = ratings[(ratings["anime_id"] == animeID) & (ratings["rating"] >= 8)]["user_id"].unique()

# %%
similar_user_recs = ratings[(ratings["user_id"].isin(similar_users)) & (ratings["rating"] >=7)]["anime_id"]

# %%
similar_user_recs = similar_user_recs.value_counts() / len(similar_users)

similar_user_recs = similar_user_recs[similar_user_recs > .1]

# %%
all_users = ratings[(ratings["anime_id"].isin(similar_user_recs.index)) & (ratings["rating"] >= 7)]

# %%
#porcentagem de recomendação de todos os usuarios que viram os filmes recomendados
all_users_recs = all_users["anime_id"].value_counts() / len(all_users["user_id"].unique())

# %%
rec_percentages = pd.concat([similar_user_recs, all_users_recs], axis=1)
rec_percentages.columns = ["similar", "all"]

# %%
#vamos selecionar os animes que possuem uma diferença grande entre a porcentagem em similar e all
rec_percentages["score"] = rec_percentages["similar"] / rec_percentages["all"]
rec_percentages = rec_percentages.sort_values("score", ascending=False)

# %%
rec_percentages.head(10).merge(animes, left_index=True, right_on="anime_id")
# Out:
#       similar       all         score  anime_id  \
# 3954      1.0  0.000072  13799.555556      5098
# 5139      0.2  0.000048   4139.866667      7779
# 3314      0.4  0.000137   2922.258824      3843
# 4673      0.3  0.000173   1732.967442      6670
# 3956      0.2  0.000141   1419.382857      5104
# 3306      0.2  0.000161   1241.960000      3835
# 3206      0.2  0.000169   1182.819048      3675
# 4125      0.2  0.000173   1155.311628      5447
# 2119      0.2  0.000181   1103.964444      2316
# 4445      0.2  0.000318    628.840506      6094
#
#                                         Name  \
# 3954                     Andersen Monogatari
# 5139                Andersen Monogatari (TV)
# 3314          Ali Baba to 40-hiki no Touzoku
# 4673  8-gatsu no Symphony: Shibuya 2002-2003
# 3956          Andes Shounen Pepero no Bouken
# 3306           Ai no Gakkou Cuore Monogatari
# 3206                       Andromeda Stories
# 4125                                  A-Girl
# 2119                      Akakichi no Eleven
# 4445               A Piece of Phantasmagoria
#
#                               English name  \
# 3954  The World of Hans Christian Andersen
# 5139                               UNKNOWN
# 3314                               UNKNOWN
# 4673                    Symphony in August
# 3956    Adventures of Pepero the Andes Boy
# 3306                               UNKNOWN
# 3206                               UNKNOWN
# 4125                                A-Girl
# 2119                               UNKNOWN
# 4445                               UNKNOWN
#
#                                           Other name Score  \
# 3954                                        アンデルセン物語  5.62
# 5139                                        アンデルセン物語  6.15
# 3314                                     アリババと４０匹の盗賊  5.42
# 4673                         8月のシンフォニー ―渋谷 2002～2003  6.53
# 3956                                    アンデス少年ペペロの冒険  6.56
# 3306                                      愛の学校 クオレ物語  6.47
# 3206                                   アンドロメダ・ストーリーズ  5.64
# 4125                                 A-Girl [エー・ガール]  5.53
# 2119                                        赤き血のイレブン  6.56
# 4445  a piece of PHANTASMAGORIA (ア・ピース・オブ ファンタスマゴリア)  6.19
#
#                               Genres  \
# 3954                  Drama, Fantasy
# 5139                  Drama, Fantasy
# 3314                 Action, Fantasy
# 4673                         UNKNOWN
# 3956                       Adventure
# 3306            Drama, Slice of Life
# 3206  Action, Drama, Fantasy, Sci-Fi
# 4125                         Romance
# 2119                          Sports
# 4445                         Fantasy
#
#                                                Synopsis  ...  \
# 3954  Hans Christian Andersen is a little boy with a...  ...
# 5139  Adaptations of numerous stories written by Han...  ...
# 3314  A film produced for Toei's 20th anniversary. A...  ...
# 4673  Based on the autobiography of the singer Kawas...  ...
# 3956  This is the quest of Pepero and his friends in...  ...
# 3306  Enrico Pocchini is a kind-hearted schoolboy wi...  ...
# 3206  In the Andromeda galaxy there's a planet of a ...  ...
# 4125  High-school student Mariko and her elder siste...  ...
# 2119  At Shinsei high school, soccer is almost a com...  ...
# 4445  A collection of 15 short episodes depicting th...  ...
#
#                Studios   Source       Duration                     Rating  \
# 3954    Toei Animation  Unknown    1 hr 20 min               G - All Ages
# 5139           UNKNOWN  Unknown  24 min per ep              PG - Children
# 3314    Toei Animation  Unknown         55 min               G - All Ages
# 4673         WAO World     Book    1 hr 52 min  PG-13 - Teens 13 or older
# 3956           UNKNOWN  Unknown  24 min per ep              PG - Children
# 3306  Nippon Animation    Novel  25 min per ep               G - All Ages
# 3206    Toei Animation    Manga    1 hr 24 min           R+ - Mild Nudity
# 4125          Madhouse    Manga         31 min  PG-13 - Teens 13 or older
# 2119           UNKNOWN  Unknown  25 min per ep  PG-13 - Teens 13 or older
# 4445           UNKNOWN  Unknown   5 min per ep               G - All Ages
#
#          Rank Popularity Favorites Scored By Members  \
# 3954  10387.0      12386         1     337.0    1078
# 5139   8090.0      12447         1     262.0    1056
# 3314  11024.0      11154         1     682.0    1682
# 4673   6177.0      11160         0     376.0    1679
# 3956   6015.0      12183         2     359.0    1157
# 3306   6513.0      10011         5     670.0    2471
# 3206  10299.0      10577         3     655.0    2059
# 4125  10687.0       8960        10    1456.0    3566
# 2119   6014.0      10561         8     567.0    2071
# 4445   7947.0       8064        26    1415.0    4935
#
#                                               Image URL
# 3954  https://cdn.myanimelist.net/images/anime/1051/...
# 5139  https://cdn.myanimelist.net/images/anime/7/690...
# 3314  https://cdn.myanimelist.net/images/anime/3/686...
# 4673  https://cdn.myanimelist.net/images/anime/9/173...
# 3956  https://cdn.myanimelist.net/images/anime/3/608...
# 3306  https://cdn.myanimelist.net/images/anime/1792/...
# 3206  https://cdn.myanimelist.net/images/anime/8/751...
# 4125  https://cdn.myanimelist.net/images/anime/12/82...
# 2119  https://cdn.myanimelist.net/images/anime/4/232...
# 4445  https://cdn.myanimelist.net/images/anime/1577/...
#
# [10 rows x 27 columns]

# %%
def find_similar_animes(anime_id):
    similar_users = ratings[(ratings["anime_id"] == anime_id) & (ratings["rating"] >= 4)]["user_id"].unique()
    similar_user_recs = ratings[(ratings["user_id"].isin(similar_users)) & (ratings["rating"] >=4)]["anime_id"]
    
    similar_user_recs = similar_user_recs.value_counts() / len(similar_users)
    similar_user_recs = similar_user_recs[similar_user_recs > .1]
    
    all_users = ratings[(ratings["anime_id"].isin(similar_user_recs.index)) & (ratings["rating"] > 4)]
    all_users_recs = all_users["anime_id"].value_counts() / len(all_users["user_id"].unique())
    
    rec_percentages = pd.concat([similar_user_recs, all_users_recs], axis=1)
    rec_percentages.columns = ["similar", "all"]
    
    rec_percentages["score"] = rec_percentages["similar"] / rec_percentages["all"]
    
    rec_percentages = rec_percentages.sort_values("score", ascending=False)
    
    return rec_percentages.head(15).merge(animes, left_index=True, right_on="anime_id")[["Score","Name","Genres"]]

# %%
#widget em que será fornecido do nome do anime
anime_input = widgets.Text(
    value = " ",
    description = "Anime Title:",
    disabled = False)

#esse é o widget que exibe os resultados de saída
anime_recommendation_list = widgets.Output()

def on_type(data):
    with anime_recommendation_list:
        anime_recommendation_list.clear_output() #limpa o output
        title = data["new"]
        if len(title) > 3:
            results = search(title)
            anime_id = results.iloc[0]["anime_id"]
            display(find_similar_animes(anime_id))

anime_input.observe(on_type, names='value') #observa sempre que há uma mudança em anime_input,
                                            #chamando automaticamente a função on_type
display(anime_input, anime_recommendation_list)
# Out:
# Text(value=' ', description='Anime Title:')
# Output()
